# %%
import pandas as pd

demagog_df  = pd.read_csv("../scrapping/demagog/dataset.csv")
demagog_df.head()
# Out:
#    Unnamed: 0   source                                                url  \
# 0           0  demagog  https://demagog.org.pl/wypowiedzi/najwyzsza-in...
# 1           1  demagog  https://demagog.org.pl/wypowiedzi/koszty-obslu...
# 2           2  demagog  https://demagog.org.pl/wypowiedzi/atom-w-polsc...
# 3           3  demagog  https://demagog.org.pl/wypowiedzi/seniorzy-ton...
# 4           4  demagog  https://demagog.org.pl/wypowiedzi/satysfakcja-...
#
#                      date              author  \
# 0  16.11.2022 godz. 10:33  Katarzyna Lubnauer
# 1  07.11.2022 godz. 16:20     Radosław Fogiel
# 2  04.11.2022 godz. 12:11      Artur Dziambor
# 3  03.11.2022 godz. 17:16     Michał Szczerba
# 4   28.10.2022 godz. 9:48     Szymon Hołownia
#
#                                                title content             label
# 0  \nNajwyższa inflacja od 26 lat. O ile skoczyły...     NaN            Prawda
# 1  \nKoszty obsługi długu mogą wzrosnąć. Ile wyno...     NaN            Prawda
# ...
